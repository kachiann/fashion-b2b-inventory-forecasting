# %%
# import libraries
import pandas as pd

# %%
# load dataset
feat_path = "../data/processed/features.csv"
df_feat = pd.read_csv(feat_path, parse_dates=["week"])
df_feat.head()
# Out:
#   partner_id sku_id category  price  lead_time_weeks       week  sales_units  \
# 0         P1   S001     tops    118                1 2022-01-31           25
# 1         P1   S001     tops    118                1 2022-02-07           39
# 2         P1   S001     tops    118                1 2022-02-14           18
# 3         P1   S001     tops    118                1 2022-02-21            9
# 4         P1   S001     tops    118                1 2022-02-28           22
#
#    weekofyear  year  sales_units_lag_1  sales_units_lag_2  sales_units_lag_3  \
# 0           5  2022               20.0               13.0               27.0
# 1           6  2022               25.0               20.0               13.0
# 2           7  2022               39.0               25.0               20.0
# 3           8  2022               18.0               39.0               25.0
# 4           9  2022                9.0               18.0               39.0
#
# ...

# %%
df_feat[[
    "sales_units",
    "sales_units_lag_1",
    "sales_units_lag_2",
    "sales_units_rollmean_4"
]].corr()
# Out:
#                         sales_units  sales_units_lag_1  sales_units_lag_2  \
# sales_units                1.000000           0.127059           0.110758
# sales_units_lag_1          0.127059           1.000000           0.126816
# sales_units_lag_2          0.110758           0.126816           1.000000
# sales_units_rollmean_4     0.585894           0.583405           0.583198
#
#                         sales_units_rollmean_4
# sales_units                           0.585894
# sales_units_lag_1                     0.583405
# sales_units_lag_2                     0.583198
# sales_units_rollmean_4                1.000000
